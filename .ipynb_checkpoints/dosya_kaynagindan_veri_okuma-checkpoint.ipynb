# %%
import findspark

# %%
findspark.init("/opt/manual/spark")

# %%
from pyspark.sql import SparkSession

# %%
spark = (SparkSession.builder
        .appName("Read Data from File")
        .master("local[2]")
        .getOrCreate())

# %%
! wget https://raw.githubusercontent.com/erkansirin78/datasets/master/spark_book_data/bike-data/201508_trip_data.csv -P ~/datasets
# Out:
# --2022-05-06 19:21:01--  https://raw.githubusercontent.com/erkansirin78/datasets/master/spark_book_data/bike-data/201508_trip_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42658497 (41M) [text/plain]
# Saving to: ‘/home/train/datasets/201508_trip_data.csv’
#
# 100%[======================================>] 42,658,497  3.01MB/s   in 14s
#
# 2022-05-06 19:21:17 (2.95 MB/s) - ‘/home/train/datasets/201508_trip_data.csv’ saved [42658497/42658497]

# %%
df = spark.read.csv("file:///home/train/datasets/201508_trip_data.csv")

# %%
df.show(5)
# Out:
# +-------+--------+---------------+--------------------+--------------+---------------+--------------------+------------+------+---------------+--------+
# |    _c0|     _c1|            _c2|                 _c3|           _c4|            _c5|                 _c6|         _c7|   _c8|            _c9|    _c10|
# +-------+--------+---------------+--------------------+--------------+---------------+--------------------+------------+------+---------------+--------+
# |Trip ID|Duration|     Start Date|       Start Station|Start Terminal|       End Date|         End Station|End Terminal|Bike #|Subscriber Type|Zip Code|
# | 913460|     765|8/31/2015 23:26|Harry Bridges Pla...|            50|8/31/2015 23:39|San Francisco Cal...|          70|   288|     Subscriber|    2139|
# | 913459|    1036|8/31/2015 23:11|San Antonio Shopp...|            31|8/31/2015 23:28|Mountain View Cit...|          27|    35|     Subscriber|   95032|
# | 913455|     307|8/31/2015 23:13|      Post at Kearny|            47|8/31/2015 23:18|   2nd at South Park|          64|   468|     Subscriber|   94107|
# | 913454|     409|8/31/2015 23:10|  San Jose City Hall|            10|8/31/2015 23:17| San Salvador at 1st|           8|    68|     Subscriber|   95113|
# +-------+--------+---------------+--------------------+--------------+---------------+--------------------+------------+------+---------------+--------+
# only showing top 5 rows

# %%
df = spark.read\
.option("header", True)\
.csv("file:///home/train/datasets/201508_trip_data.csv")

# %%
df.show(5)
# Out:
# +-------+--------+---------------+--------------------+--------------+---------------+--------------------+------------+------+---------------+--------+
# |Trip ID|Duration|     Start Date|       Start Station|Start Terminal|       End Date|         End Station|End Terminal|Bike #|Subscriber Type|Zip Code|
# +-------+--------+---------------+--------------------+--------------+---------------+--------------------+------------+------+---------------+--------+
# | 913460|     765|8/31/2015 23:26|Harry Bridges Pla...|            50|8/31/2015 23:39|San Francisco Cal...|          70|   288|     Subscriber|    2139|
# | 913459|    1036|8/31/2015 23:11|San Antonio Shopp...|            31|8/31/2015 23:28|Mountain View Cit...|          27|    35|     Subscriber|   95032|
# | 913455|     307|8/31/2015 23:13|      Post at Kearny|            47|8/31/2015 23:18|   2nd at South Park|          64|   468|     Subscriber|   94107|
# | 913454|     409|8/31/2015 23:10|  San Jose City Hall|            10|8/31/2015 23:17| San Salvador at 1st|           8|    68|     Subscriber|   95113|
# | 913453|     789|8/31/2015 23:09|Embarcadero at Fo...|            51|8/31/2015 23:22|Embarcadero at Sa...|          60|   487|       Customer|    9069|
# +-------+--------+---------------+--------------------+--------------+---------------+--------------------+------------+------+---------------+--------+
# only showing top 5 rows

# %%
df.printSchema()
# Out:
# root
#  |-- Trip ID: string (nullable = true)
#  |-- Duration: string (nullable = true)
#  |-- Start Date: string (nullable = true)
#  |-- Start Station: string (nullable = true)
#  |-- Start Terminal: string (nullable = true)
#  |-- End Date: string (nullable = true)
#  |-- End Station: string (nullable = true)
#  |-- End Terminal: string (nullable = true)
#  |-- Bike #: string (nullable = true)
#  |-- Subscriber Type: string (nullable = true)
#  |-- Zip Code: string (nullable = true)

# %%
df = spark.read\
.option("header", True)\
.option("inferSchema", True)\
.csv("file:///home/train/datasets/201508_trip_data.csv")

# %%
df.printSchema()
# Out:
# root
#  |-- Trip ID: integer (nullable = true)
#  |-- Duration: integer (nullable = true)
#  |-- Start Date: string (nullable = true)
#  |-- Start Station: string (nullable = true)
#  |-- Start Terminal: integer (nullable = true)
#  |-- End Date: string (nullable = true)
#  |-- End Station: string (nullable = true)
#  |-- End Terminal: integer (nullable = true)
#  |-- Bike #: integer (nullable = true)
#  |-- Subscriber Type: string (nullable = true)
#  |-- Zip Code: string (nullable = true)

# %%
df.limit(20).toPandas()
# Out:
#     Trip ID  Duration       Start Date  \
# 0    913460       765  8/31/2015 23:26
# 1    913459      1036  8/31/2015 23:11
# 2    913455       307  8/31/2015 23:13
# 3    913454       409  8/31/2015 23:10
# 4    913453       789  8/31/2015 23:09
# 5    913452       293  8/31/2015 23:07
# 6    913451       896  8/31/2015 23:07
# 7    913450       255  8/31/2015 22:16
# 8    913449       126  8/31/2015 22:12
# 9    913448       932  8/31/2015 21:57
# 10   913443       691  8/31/2015 21:49
# 11   913442       633  8/31/2015 21:44
# 12   913441       387  8/31/2015 21:39
# 13   913440       281  8/31/2015 21:31
# 14   913435       424  8/31/2015 21:25
# 15   913434       283  8/31/2015 21:19
# 16   913433       145  8/31/2015 21:17
# 17   913432       703  8/31/2015 21:16
# 18   913431       605  8/31/2015 21:11
# 19   913429       902  8/31/2015 21:07
#
#                                     Start Station  Start Terminal  \
# 0            Harry Bridges Plaza (Ferry Building)              50
# 1                     San Antonio Shopping Center              31
# 2                                  Post at Kearny              47
# 3                              San Jose City Hall              10
# 4                           Embarcadero at Folsom              51
# 5   Yerba Buena Center of the Arts (3rd @ Howard)              68
# 6                           Embarcadero at Folsom              51
# 7                          Embarcadero at Sansome              60
# 8                                 Beale at Market              56
# 9                                  Post at Kearny              47
# 10                         Embarcadero at Sansome              60
# 11                                 Market at 10th              67
# 12                                  Market at 4th              76
# 13                              Market at Sansome              77
# 14  Temporary Transbay Terminal (Howard at Beale)              55
# 15        San Francisco Caltrain 2 (330 Townsend)              69
# 16                         University and Emerson              35
# 17                                Spear at Folsom              49
# 18  Temporary Transbay Terminal (Howard at Beale)              55
# 19       San Francisco Caltrain (Townsend at 4th)              70
#
#            End Date                                    End Station  \
# 0   8/31/2015 23:39       San Francisco Caltrain (Townsend at 4th)
# 1   8/31/2015 23:28                        Mountain View City Hall
# 2   8/31/2015 23:18                              2nd at South Park
# 3   8/31/2015 23:17                            San Salvador at 1st
# 4   8/31/2015 23:22                         Embarcadero at Sansome
# 5   8/31/2015 23:12       San Francisco Caltrain (Townsend at 4th)
# 6   8/31/2015 23:22                         Embarcadero at Sansome
# 7   8/31/2015 22:20                              Steuart at Market
# 8   8/31/2015 22:15  Temporary Transbay Terminal (Howard at Beale)
# 9   8/31/2015 22:12                       South Van Ness at Market
# 10  8/31/2015 22:01                              Market at Sansome
# 11  8/31/2015 21:54       San Francisco Caltrain (Townsend at 4th)
# 12  8/31/2015 21:46                Grant Avenue at Columbus Avenue
# 13  8/31/2015 21:36                      Broadway St at Battery St
# 14  8/31/2015 21:33        San Francisco Caltrain 2 (330 Townsend)
# 15  8/31/2015 21:24                                Townsend at 7th
# 16  8/31/2015 21:20                           Cowper at University
# 17  8/31/2015 21:28        San Francisco Caltrain 2 (330 Townsend)
# 18  8/31/2015 21:21                Grant Avenue at Columbus Avenue
# 19  8/31/2015 21:22                      Broadway St at Battery St
#
#     End Terminal  Bike # Subscriber Type Zip Code
# 0             70     288      Subscriber     2139
# 1             27      35      Subscriber    95032
# 2             64     468      Subscriber    94107
# 3              8      68      Subscriber    95113
# 4             60     487        Customer     9069
# 5             70     538      Subscriber    94118
# 6             60     363        Customer    92562
# 7             74     470      Subscriber    94111
# 8             55     439      Subscriber    94130
# 9             66     472      Subscriber    94702
# 10            77     434      Subscriber    94109
# 11            70     531      Subscriber    94107
# 12            73     383      Subscriber    94104
# 13            82     621      Subscriber    94107
# 14            69     602      Subscriber    94401
# 15            65     521      Subscriber    94107
# 16            37      75        Customer     6907
# 17            69     426      Subscriber    95032
# 18            73     572      Subscriber    94133
# 19            82     501      Subscriber    94133

# %%
spark.stop()
